# %% [markdown]
# # Web Scaraping Assignment -3

# %% [markdown]
# Name -Sucharitha A M
# Batch -internship batch 16

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd 
from selenium import webdriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from
# www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars

# %%
url='https://www.amazon.in/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e2266d6816d91cc98b6a043b0daf75ab", element="a7e64226-7588-407a-9961-3a49c22b72d0")>

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages
# of your search results and save it in a dataframe and csv. In case if any product has less than 3
# pages in search results then scrape all the products available under that product vertical.
# Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings",
# "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it

# %%
from selenium import webdriver
import time

# %%
brand_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='a-size a-color-base']"):
        brand_tags.append(j.text) 
    time.sleep(5)

# %%
brand_tags
# Out:
# ['',
#  '',
#  '.in',
#  'Hello\nSelect your address',
#  'Hello',
#  'Select your address',
#  'All',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Hello, Sign in',
#  'Account & Lists',
#  '',
#  'Returns',
#  '& Orders',
#  '0',
#  '',
#  '',
#  'Cart',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'All',
#  'Prime',
#  '',
#  '1-48 of 262 results for "guiter"\nSort by:\nFeatured\nPrice: Low to High\nPrice: High to Low\nAvg. Customer Review\nNewest Arrivals\nSort by:Featured',
#  '1-48 of 262 results for "guiter"\nSort by:\nFeatured\nPrice: Low to High\nPrice: High to Low\nAvg. Customer Review\nNewest Arrivals\nSort by:Featured',
#  '1-48 of 262 results for',
#  '',
#  '"guiter"',
#  'Sort by:\nFeatured\nPrice: Low to High\nPrice: High to Low\nAvg. Customer Review\nNewest Arrivals\nSort by:Featured',
#  'Sort by:Featured',
#  'Sort by:Featured',
#  'Sort by:Featured',
#  'Sort by:',
# ...

# %%
product_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='a-size-base a-color-tertiary']"):
        product_tags.append(j.text) 
    time.sleep(5)

# %%
product_tags
# Out:
# ['Brazilian Rosewood',
#  'Carbon',
#  'Indian Rosewood',
#  'Pau Fero',
#  'Peroba',
#  'Acacia',
#  'Alder',
#  'Basswood',
#  'Birds-Eye Maple',
#  'Brazilian Rosewood',
#  'Burl wood',
#  'Carbon',
#  'Ebony',
#  'Hard Maple',
#  'Indian Rosewood',
#  'Korina',
#  'Nato',
#  'Paduak',
#  'Pau Marfin',
#  'Peroba',
#  'Poplar',
#  'Rock Maple',
#  'Sapele',
#  'Walnut',
#  'Wenge',
#  '5',
#  '7',
#  '8',
#  '9',
#  '10',
#  '11',
#  '12',
#  'Used',
#  'Brazilian Rosewood',
#  'Carbon',
#  'Indian Rosewood',
#  'Pau Fero',
#  'Peroba',
#  'Acacia',
#  'Alder',
#  'Basswood',
#  'Birds-Eye Maple',
#  'Brazilian Rosewood',
#  'Burl wood',
#  'Carbon',
#  'Ebony',
#  'Hard Maple',
#  'Indian Rosewood',
#  'Korina',
#  'Nato',
#  'Paduak',
#  'Pau Marfin',
#  'Peroba',
#  'Poplar',
#  'Rock Maple',
#  'Sapele',
#  'Walnut',
#  'Wenge',
#  '5',
#  '7',
#  '8',
#  '9',
#  '10',
#  '11',
#  '12',
#  'Used',
#  'Brazilian Rosewood',
#  'Carbon',
#  'Indian Rosewood',
#  'Pau Fero',
# ...

# %%
rating_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//i"):
        rating_tags.append(j.text) 
    time.sleep(5)

# %%
rating_tags
# Out:
# ['',
#  '',
#  '.in',
#  'Hello\nSelect your address',
#  'Hello',
#  'Select your address',
#  'Musical Instruments',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Hello, Sign in',
#  'Account & Lists',
#  '',
#  'Returns',
#  '& Orders',
#  '0',
#  '',
#  '',
#  'Cart',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'All',
#  'Prime',
#  '',
#  '',
#  'Mobiles & Accessories',
#  '',
#  'Laptops & Accessories',
#  '',
#  'TV & Home Entertainment',
#  '',
#  'Audio',
#  '',
#  'Cameras',
#  '',
#  'Computer Peripherals',
#  '',
#  'Smart Technology',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Musical Instruments',
#  '›',
#  'Guitars, Basses & Gear',
#  '›',
#  'Accessories',
#  '›',
#  'Picks & Pick Holders',
#  '›',
#  'Picks',
#  '›',
#  'AmazonBasics Guitar Picks, Mixed Colors, Celluloid, 10-Pieces',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Add to Cart',
#  'Add to Cart',
#  'Add to Cart',
# ...

# %%
Ratings_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='a-size-base']"):
        Ratings_tags.append(j.text) 
    time.sleep(5)

# %%
Ratings_tags
# Out:
# ['10,319',
#  '167',
#  '3,522',
#  '3,631',
#  '1',
#  '337',
#  '207',
#  '5',
#  '780',
#  '115',
#  '1,162',
#  '44',
#  '2,947',
#  '3',
#  '68',
#  '454',
#  '43',
#  '479',
#  '43',
#  '16',
#  '2',
#  '3',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '10,319',
#  '167',
#  '3,522',
#  '3,631',
#  '1',
#  '337',
#  '207',
#  '5',
#  '780',
#  '115',
#  '1,162',
#  '44',
#  '2,947',
#  '3',
#  '68',
#  '454',
#  '43',
#  '479',
#  '43',
#  '16',
#  '2',
#  '3',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '10,319',
#  '167',
#  '3,522',
#  '3,631',
#  '1',
#  '337',
#  '207',
#  '5',
#  '780',
#  '115',
#  '1,162',
#  '44',
#  '2,947',
#  '3',
#  '68',
#  '454',
#  '43',
#  '479',
#  '43',
#  '16',
#  '2',
#  '3',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '10,319',
#  '167',
#  '3,522',
#  '3,631',
#  '1',
#  '337',
#  '207',
#  '5',
#  '780',
#  '115',
#  '1,162',
#  '44',
#  '2,947',
# ...

# %%
price_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='a-price-whole']"):
        price_tags.append(j.text) 
    time.sleep(5)

# %%
price_tags
# Out:
# ['2,499',
#  '2,369',
#  '2,499',
#  '2,499',
#  '4,169',
#  '2,499',
#  '2,250',
#  '4,839',
#  '2,635',
#  '3,179',
#  '2,584',
#  '2,810',
#  '3,490',
#  '2,279',
#  '4,509',
#  '2,250',
#  '2,847',
#  '4,399',
#  '2,499',
#  '2,499',
#  '3,019',
#  '3,479',
#  '4,664',
#  '4,921',
#  '2,499',
#  '2,369',
#  '2,499',
#  '2,499',
#  '4,169',
#  '2,499',
#  '2,250',
#  '4,839',
#  '2,635',
#  '3,179',
#  '2,584',
#  '2,810',
#  '3,490',
#  '2,279',
#  '4,509',
#  '2,250',
#  '2,847',
#  '4,399',
#  '2,499',
#  '2,499',
#  '3,019',
#  '3,479',
#  '4,664',
#  '4,921',
#  '2,499',
#  '2,369',
#  '2,499',
#  '2,499',
#  '4,169',
#  '2,499',
#  '2,250',
#  '4,839',
#  '2,635',
#  '3,179',
#  '2,584',
#  '2,810',
#  '3,490',
#  '2,279',
#  '4,509',
#  '2,250',
#  '2,847',
#  '4,399',
#  '2,499',
#  '2,499',
#  '3,019',
#  '3,479',
#  '4,664',
#  '4,921',
#  '2,499',
#  '2,369',
#  '2,499',
#  '2,499',
#  '4,169',
#  '2,499',
#  '2,250',
#  '4,839',
#  '2,635',
#  '3,179',
#  '2,584',
# ...

# %%
exchange_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a"):
        exchange_tags.append(j.text) 
    time.sleep(5)

# %%
exchange_tags
# Out:
# ['Skip to main content\n.in\nHello\nSelect your address\nMusical Instruments\nAll Categories\nDeals\nAlexa Skills\nAmazon Devices\nAmazon Fashion\nAmazon Fresh\nAmazon Pantry\nAppliances\nApps & Games\nBaby\nBeauty\nBooks\nCar & Motorbike\nClothing & Accessories\nCollectibles\nComputers & Accessories\nElectronics\nFurniture\nGarden & Outdoors\nGift Cards\nGrocery & Gourmet Foods\nHealth & Personal Care\nHome & Kitchen\nIndustrial & Scientific\nJewellery\nKindle Store\nLuggage & Bags\nLuxury Beauty\nMovies & TV Shows\nMusic\nMusical Instruments\nOffice Products\nPet Supplies\nPrime Video\nShoes & Handbags\nSoftware\nSports, Fitness & Outdoors\nTools & Home Improvement\nToys & Games\nUnder ₹500\nVideo Games\nWatches\nHello, Sign in\nAccount & Lists\nReturns\n& Orders\n0\nCart\nAll\nBest Sellers\nMobiles\nFashion\nElectronics\nPrime\nNew Releases\nMobiles & Accessories\nLaptops & Accessories\nTV & Home Entertainment\nAudio\nCameras\nComputer Peripherals\nSmart Technology\n1-24 of 80 res
# ...

# %%
delivery_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='a-text-bold']"):
        delivery_tags.append(j.text) 
    time.sleep(5)

# %%
delivery_tags
# Out:
# ['Friday, June 25',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Thursday, June 24',
#  'Saturday, June 26',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Wednesday, June 30',
#  'Saturday, June 26',
#  'Sunday, June 27',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Thursday, June 24',
#  'Monday, June 28',
#  'Thursday, June 24',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Thursday, June 24',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Thursday, June 24',
#  'Saturday, June 26',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Wednesday, June 30',
#  'Saturday, June 26',
#  'Sunday, June 27',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Thursday, June 24',
#  'Monday, June 28',
#  'Thursday, June 24',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Friday, June 25',
#  'Thursday, June 24',
#  'Friday, June 25',
# ...

# %%
availability_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='a-size-base a-color-base']"):
        availability_tags.append(j.text) 
    time.sleep(5)

# %%
availability_tags
# Out:
# ['or',
#  'Get It in 2 Days',
#  'Any Department',
#  'Guitars, Basses & Gear',
#  'Guitars, Basses & Kits',
#  'Guitar & Bass Kits',
#  'Acoustic Guitar Kits',
#  'Juârez',
#  'Intern',
#  'Kadence',
#  'YAMAHA',
#  'VAULT',
#  'Generic',
#  'Jixing',
#  'blueberry',
#  'DOMENICO',
#  'ARCTIC',
#  'KETOSTICS',
#  'GIVSON',
#  'Fender',
#  'Cort',
#  'RockJam',
#  'Martin Smith',
#  'Alvarez',
#  'GIVSUN',
#  'Sora',
#  'Epiphone',
#  'SG Musical',
#  'Hertz',
#  'Donner',
#  'APLINK',
#  'Any Price',
#  "Today's Deals",
#  'Made for Amazon',
#  'Eligible for Pay On Delivery',
#  'Ebony',
#  'Rosewood',
#  'Basswood',
#  'Right-Handed',
#  '6',
#  'New',
#  'Any Discount',
#  '25% Off or more',
#  '35% Off or more',
#  '50% Off or more',
#  'Cart2India SLP',
#  'Appario Retail Private Ltd',
#  'Global_Reseller',
#  'Bajaao',
#  'GetUSCart',
#  'Sat-exm',
#  'VAVIM',
#  'Big Shoppe Store',
#  'Futabatech',
#  'MISUOGUITAR IN',
#  'Include Out of Stock',
#  'or',
# ...

# %%
producturl_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//h2"):
        producturl_tags.append(j.text) 
    time.sleep(5)

# %%
producturl_tags
# Out:
# ['Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Juarez Acoustic Guitar, 38 Inch Cutaway, 38CMB with Bag, Strings, Pick and Strap, Matte Black',
#  'Juarez JRZ38C Acoustic Guitar, 38 Inch Cutaway with Bag (TBS Transparent Blue Sunburst)',
#  'JUAREZ JRZ38C Right Handed Acoustic Guitar (Sunburst, 6 Strings)',
#  'ARCTIC Vigor Acoustic Guitar package with 40 inches Folk steel string Guitar Curved shape with Bag, Capo & Picks (Blue)',
#  'Juârez JRZ38C/WH 6 Strings Acoustic Guitar 38 Inch Cutaway, Right Handed, White with Bag, Strings, Picks and Strap',
#  'Juarez Acoustic Guitar, 38 Inch Cutaway with Pick Guard, 38CPG with Bag, Strings, Pick and Strap, Black',
#  'JUAREZ Arpeggio 41 Inch Acoustic Guitar Kit, Spruce Top, Rosewood Fretboard & Bridge, Truss Rod, Chrome Die Cast Machine Tuners, Red',
#  'Intern INT-38C-NT-G Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Natural, 6-Strings)',
# ...

# %%
discount_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='a-size-base a-color-base a-text-bold']"):
        discount_tags.append(j.text) 
    time.sleep(5)

# %%
discount_tags
# Out:
# ['Department',
#  'Musical Instruments',
#  'Avg. Customer Review',
#  'Brand',
#  'Price',
#  '₹1,000 - ₹5,000',
#  'Deals',
#  'Pay On Delivery',
#  'Guitar Fretboard Material',
#  'Hand Orientation',
#  'Number of Strings',
#  'Item Condition',
#  'Discount',
#  'Seller',
#  'Availability',
#  'Department',
#  'Musical Instruments',
#  'Avg. Customer Review',
#  'Brand',
#  'Price',
#  '₹1,000 - ₹5,000',
#  'Deals',
#  'Pay On Delivery',
#  'Guitar Fretboard Material',
#  'Hand Orientation',
#  'Number of Strings',
#  'Item Condition',
#  'Discount',
#  'Seller',
#  'Availability',
#  'Department',
#  'Musical Instruments',
#  'Avg. Customer Review',
#  'Brand',
#  'Price',
#  '₹1,000 - ₹5,000',
#  'Deals',
#  'Pay On Delivery',
#  'Guitar Fretboard Material',
#  'Hand Orientation',
#  'Number of Strings',
#  'Item Condition',
#  'Discount',
#  'Seller',
#  'Availability',
#  'Department',
#  'Musical Instruments',
#  'Avg. Customer Review',
#  'Brand',
#  'Price',
# ...

# %%
seller_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='a-size-base a-color-base']"):
        seller_tags.append(j.text) 
    time.sleep(5)

# %%
seller_tags
# Out:
# ['or',
#  'Any Department',
#  'Guitars, Basses & Gear',
#  'Guitars, Basses & Kits',
#  'Guitar & Bass Kits',
#  'Acoustic Guitar Kits',
#  'Juârez',
#  'Intern',
#  'Kadence',
#  'YAMAHA',
#  'VAULT',
#  'Generic',
#  'Jixing',
#  'blueberry',
#  'DOMENICO',
#  'ARCTIC',
#  'KETOSTICS',
#  'GIVSON',
#  'Fender',
#  'Cort',
#  'RockJam',
#  'Martin Smith',
#  'Alvarez',
#  'GIVSUN',
#  'Sora',
#  'Epiphone',
#  'SG Musical',
#  'Hertz',
#  'Donner',
#  'APLINK',
#  'Any Price',
#  "Today's Deals",
#  'Eligible for Pay On Delivery',
#  'Ebony',
#  'Rosewood',
#  'Right-Handed',
#  '6',
#  'New',
#  '10% Off or more',
#  '25% Off or more',
#  '35% Off or more',
#  '50% Off or more',
#  'Appario Retail Private Ltd',
#  'Global_Reseller',
#  'Cart2India SLP',
#  'GetUSCart',
#  'Nitrous Stores',
#  'Sat-exm',
#  'STS Shop',
#  'VAVIM',
#  'Andoerin',
#  'ASCENTREK',
#  'Include Out of Stock',
#  'or',
#  'Any Department',
#  'Guitars, Basses & Gear',
#  'Guitars, Basses & Kits',
# ...

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and
# scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
import selenium
import pandas as pd 
from selenium import webdriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
from selenium import webdriver
import time

# %%
url='https://images.google.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="b711e0f34fc193792ab3474e2e9df61a", element="fff5150c-2171-41ef-a1da-5a47cd60c852")>

# %%
fruits_images=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='uCURQ _3CVLp']"):
        fruits_images.append(j.text) 
    time.sleep(5)

# %%
fruits_images
# Out:
# ['Fruit',
#  'Food',
#  'Plant',
#  'Citrus Fruit',
#  'Orange',
#  'Produce',
#  'Fruits Image',
#  'Yellow',
#  'Food And Drink',
#  'Food Photographer',
#  'Food Photo',
#  'Lemon',
#  'Fruit',
#  'Food',
#  'Plant',
#  'Citrus Fruit',
#  'Orange',
#  'Produce',
#  'Fruits Image',
#  'Yellow',
#  'Food And Drink',
#  'Food Photographer',
#  'Food Photo',
#  'Lemon',
#  'Traffic',
#  'Car',
#  'Mercedes',
#  'Sports Car',
#  'Lamborghini',
#  'Audi',
#  'Mustang',
#  'Motorbike',
#  'Road',
#  'Jdm',
#  'Driving',
#  'Nature',
#  'Traffic',
#  'Car',
#  'Mercedes',
#  'Sports Car',
#  'Lamborghini',
#  'Audi',
#  'Mustang',
#  'Motorbike',
#  'Road',
#  'Jdm',
#  'Driving',
#  'Nature',
#  'Traffic',
#  'Car',
#  'Mercedes',
#  'Sports Car',
#  'Lamborghini',
#  'Audi',
#  'Mustang',
#  'Motorbike',
#  'Road',
#  'Jdm',
#  'Driving',
#  'Nature',
#  'Traffic',
#  'Car',
#  'Mercedes',
#  'Sports Car',
#  'Lamborghini',
#  'Audi',
#  'Mustang',
#  'Motorbike',
#  'Road',
#  'Jdm',
# ...

# %%
cars_images=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='uCURQ _3CVLp']"):
        cars_images.append(j.text) 
    time.sleep(5)

# %%
cars_images
# Out:
# ['Traffic',
#  'Car',
#  'Mercedes',
#  'Sports Car',
#  'Lamborghini',
#  'Audi',
#  'Mustang',
#  'Motorbike',
#  'Road',
#  'Jdm',
#  'Driving',
#  'Nature',
#  'Traffic',
#  'Car',
#  'Mercedes',
#  'Sports Car',
#  'Lamborghini',
#  'Audi',
#  'Mustang',
#  'Motorbike',
#  'Road',
#  'Jdm',
#  'Driving',
#  'Nature',
#  'Robot',
#  'Technology',
#  'Data',
#  'Data Science',
#  'Artificial Intelligence',
#  'Neural Network',
#  'Deep Learning',
#  'Machine',
#  'Datum',
#  'Tech',
#  'Light',
#  'Robot',
#  'Technology',
#  'Data',
#  'Data Science',
#  'Artificial Intelligence',
#  'Neural Network',
#  'Deep Learning',
#  'Machine',
#  'Datum',
#  'Tech',
#  'Light',
#  'Robot',
#  'Technology',
#  'Data',
#  'Data Science',
#  'Artificial Intelligence',
#  'Neural Network',
#  'Deep Learning',
#  'Machine',
#  'Datum',
#  'Tech',
#  'Light',
#  'Robot',
#  'Technology',
#  'Data',
#  'Data Science',
#  'Artificial Intelligence',
#  'Neural Network',
#  'Deep Learning',
# ...

# %%
MachineLearning_images=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//a"):
        MachineLearning_images.append(j.text) 
    time.sleep(5)

# %%
MachineLearning_images
# Out:
# ['',
#  '',
#  'Explore',
#  'Blog',
#  'Login',
#  'Join free',
#  'Photos\n 10k',
#  'Collections\n 10k',
#  'Users\n 12',
#  'Robot',
#  'Technology',
#  'Data',
#  'Data Science',
#  'Artificial Intelligence',
#  'Neural Network',
#  'Deep Learning',
#  'Machine',
#  'Datum',
#  'Tech',
#  'Light',
#  '',
#  '',
#  '',
#  '',
#  'HD Screen Wallpapers',
#  'Coding',
#  'HD Computer Wallpapers',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'People Images & Pictures',
#  'Human',
#  '',
#  '',
#  '',
#  '',
#  'Coding',
#  'HD Computer Wallpapers',
#  '360 Rue Saint-Jacques',
#  '',
#  '',
#  '',
#  '',
#  'People Images & Pictures',
#  'Female',
#  'Girls Photos & Images',
#  '',
#  '',
#  '',
#  '',
#  'People Images & Pictures',
#  'People Images & Pictures',
#  'Human',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'People Images & Pictures',
#  'Human',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Texture Backgrounds',
#  'HD Pattern Wallpapers',
#  'Light Backgrounds',
#  '',
# ...

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page.
# Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”,
# “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
# Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. In
# case if any of the details is missing then replace it by “- “. Save your results in a dataframe
# and CSV.

# %%
import selenium
import pandas as pd 
from selenium import webdriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
from selenium import webdriver
import time

# %%
url='https://www.flipkart.com/'
driver.get(url)

# %%
search_bar = driver.find_element_by_class_name("_3704LK")
search_bar.send_keys(' pixel 4A')

# %%
search_button=driver.find_element_by_class_name('L0Z3Pu')
search_button.click()

# %%
brand=[]
displaysize=[]
displayresolution=[]
processor=[]
processorcores=[]
Smartphonename=[]
Colour=[]
RAM=[]
Storage=[]
primarycamera=[]
secondarycamera=[]
batterycapacity=[]
price=[]
producturl=[]

# %%
brand_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='_2gmUFU _3V8rao']"):
        brand_name.append(j.text) 
    time.sleep(5)

# %%
brand_name
# Out:
# ['RAM',
#  'BRAND',
#  'CUSTOMER RATINGS',
#  'INTERNAL STORAGE',
#  'BATTERY CAPACITY',
#  'OPERATING SYSTEM',
#  'NETWORK TYPE',
#  'SCREEN SIZE',
#  'SIM TYPE',
#  'PRIMARY CAMERA',
#  'SECONDARY CAMERA',
#  'OFFERS',
#  'PROCESSOR BRAND',
#  'SPECIALITY',
#  'RESOLUTION TYPE',
#  'TYPE',
#  'OPERATING SYSTEM VERSION NAME',
#  'AVAILABILITY',
#  'CLOCK SPEED',
#  'FEATURES',
#  'NUMBER OF CORES',
#  'BUDGET',
#  'GST INVOICE AVAILABLE',
#  'RAM',
#  'BRAND',
#  'CUSTOMER RATINGS',
#  'INTERNAL STORAGE',
#  'BATTERY CAPACITY',
#  'OPERATING SYSTEM',
#  'NETWORK TYPE',
#  'SCREEN SIZE',
#  'SIM TYPE',
#  'PRIMARY CAMERA',
#  'SECONDARY CAMERA',
#  'OFFERS',
#  'PROCESSOR BRAND',
#  'SPECIALITY',
#  'RESOLUTION TYPE',
#  'TYPE',
#  'OPERATING SYSTEM VERSION NAME',
#  'AVAILABILITY',
#  'CLOCK SPEED',
#  'FEATURES',
#  'NUMBER OF CORES',
#  'BUDGET',
#  'GST INVOICE AVAILABLE',
#  'RAM',
#  'BRAND',
#  'CUSTOMER RATINGS',
#  'INTERNAL STORAGE',
#  'BATTERY CAPACITY',
# ...

# %%
displaysize_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//li"):
        displaysize_tags.append(j.text) 
    time.sleep(5)

# %%
displaysize_tags
# Out:
# ['6 GB RAM | 128 GB ROM',
#  '14.76 cm (5.81 inch) Full HD+ Display',
#  '12.2MP Rear Camera | 8MP Front Camera',
#  '3140 mAh Battery',
#  'Qualcomm Snapdragon 730G Processor',
#  'OLED Display',
#  '1 Year Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G85 Processor',
#  '1 Year Manufacturer Warranty for Device and 6 months Manufacturer Warranty for In-box Accessories Including Batteries from the Date of Purchase',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '13MP Rear Camera | 8MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G80 Processor',
#  '1 Year Manufacturer Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
# ...

# %%
processor_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='_3879cV']"):
        processor_tags.append(j.text) 
    time.sleep(5)

# %%
processor_tags
# Out:
# ['',
#  '6 GB & Above',
#  '4 GB',
#  '3 GB',
#  '2 GB',
#  '1 GB',
#  'SAMSUNG',
#  'Mi',
#  'OPPO',
#  'LG',
#  'Nokia',
#  'Micromax',
#  '4★ & above',
#  '3★ & above',
#  '2★ & above',
#  '1★ & above',
#  'Exchange Offer',
#  'No Cost EMI',
#  'Special Price',
#  'Buy More, Save More',
#  'Mediatek',
#  'Exynos',
#  'Huawei',
#  'Snapdragon',
#  'Spreadtrum',
#  'Unisoc',
#  '',
#  '6 GB & Above',
#  '4 GB',
#  '3 GB',
#  '2 GB',
#  '1 GB',
#  'SAMSUNG',
#  'Mi',
#  'OPPO',
#  'LG',
#  'Nokia',
#  'Micromax',
#  '4★ & above',
#  '3★ & above',
#  '2★ & above',
#  '1★ & above',
#  'Exchange Offer',
#  'No Cost EMI',
#  'Special Price',
#  'Buy More, Save More',
#  'Mediatek',
#  'Exynos',
#  'Huawei',
#  'Snapdragon',
#  'Spreadtrum',
#  'Unisoc',
#  '',
#  '6 GB & Above',
#  '4 GB',
#  '3 GB',
#  '2 GB',
#  '1 GB',
#  'SAMSUNG',
#  'Mi',
#  'OPPO',
#  'LG',
#  'Nokia',
#  'Micromax',
#  '4★ & above',
#  '3★ & above',
#  '2★ & above',
#  '1★ & above',
#  'Exchange Offer',
# ...

# %%
processorcore_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//li"):
        processorcore_tags.append(j.text) 
    time.sleep(5)

# %%
processorcore_tags
# Out:
# ['6 GB RAM | 128 GB ROM',
#  '14.76 cm (5.81 inch) Full HD+ Display',
#  '12.2MP Rear Camera | 8MP Front Camera',
#  '3140 mAh Battery',
#  'Qualcomm Snapdragon 730G Processor',
#  'OLED Display',
#  '1 Year Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G85 Processor',
#  '1 Year Manufacturer Warranty for Device and 6 months Manufacturer Warranty for In-box Accessories Including Batteries from the Date of Purchase',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '13MP Rear Camera | 8MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G80 Processor',
#  '1 Year Manufacturer Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
# ...

# %%
smartphonename_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='_3879cV']"):
        smartphonename_tags.append(j.text) 
    time.sleep(5)

# %%
smartphonename_tags
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '6 GB & Above',
#  '4 GB',
#  '3 GB',
#  '2 GB',
#  '1 GB',
#  '512 MB - 1 GB',
#  'Less than 512 MB',
#  'SAMSUNG',
#  'Mi',
#  'OPPO',
#  'LG',
#  'ViVO',
#  'Nokia',
#  '4★ & above',
#  '3★ & above',
#  '2★ & above',
#  '1★ & above',
#  'Buy More, Save More',
#  'Exchange Offer',
#  'No Cost EMI',
#  'Special Price',
#  'Exynos',
#  'Huawei',
#  'Mediatek',
#  'Snapdragon',
#  'Spreadtrum',
#  'Unisoc',
#  'Big Storage',
#  'Higher Performance',
#  'Long-Lasting Battery',
#  'Selfie Camera',
#  'Full HD',
#  'Full HD+',
#  'FWVGA',
#  'HD',
#  'HD+',
#  'HVGA',
#  'Quad HD',
#  'Quad HD+',
#  'QVGA',
#  'Super Retina HD Display',
#  'WVGA',
#  'Smartphones',
#  'Feature Phones',
#  'Dual Core',
#  'Hexa Core',
#  'Octa Core',
#  'Quad Core',
#  'Single Core',
#  '',
#  '6 GB & Above',
#  '4 GB',
#  '3 GB',
#  '2 GB',
#  '1 GB',
#  '512 MB - 1 GB',
#  'Less than 512 MB',
#  'SAMSUNG',
#  'Mi',
#  'OPPO',
# ...

# %%
color_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//li"):
        color_tags.append(j.text) 
    time.sleep(5)

# %%
color_tags
# Out:
# ['6 GB RAM | 128 GB ROM',
#  '14.76 cm (5.81 inch) Full HD+ Display',
#  '12.2MP Rear Camera | 8MP Front Camera',
#  '3140 mAh Battery',
#  'Qualcomm Snapdragon 730G Processor',
#  'OLED Display',
#  '1 Year Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G85 Processor',
#  '1 Year Manufacturer Warranty for Device and 6 months Manufacturer Warranty for In-box Accessories Including Batteries from the Date of Purchase',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '13MP Rear Camera | 8MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G80 Processor',
#  '1 Year Manufacturer Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
# ...

# %%
ram_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//li"):
        ram_tags.append(j.text) 
    time.sleep(5)

# %%
ram_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  '',
#  'PRICE',
#  '?',
#  '39 MORE',
#  'Need help?',
#  'Help me decide',
#  'Showing 1 – 24 of 286 results for " pixel 4A"',
#  'pixel 4A',
#  'Sort By',
#  '',
#  'Add to Compare',
#  '4.6',
#  '22,256 Ratings & 3,870 Reviews',
#  '22,256 Ratings & 3,870 Reviews',
#  '22,256 Ratings ',
#  '&',
#  ' 3,870 Reviews',
#  '',
#  'Add to Compare',
#  '4.4',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings ',
#  '&',
#  ' 3,525 Reviews',
#  '26% off',
#  '',
#  'Add to Compare',
#  '4.4',
#  '1,18,232 Ratings & 7,940 Reviews',
#  '1,18,232 Ratings & 7,940 Reviews',
#  '1,18,232 Ratings ',
#  '&',
#  ' 7,940 Reviews',
#  '16% off',
#  'Temporarily Unavailable',
#  '',
#  'Add to Compare',
#  '4.4',
#  '47,914 Ratings & 3,525 Reviews',
# ...

# %%
storage_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//li"):
        storage_tags.append(j.text) 
    time.sleep(5)

# %%
storage_tags
# Out:
# ['6 GB RAM | 128 GB ROM',
#  '14.76 cm (5.81 inch) Full HD+ Display',
#  '12.2MP Rear Camera | 8MP Front Camera',
#  '3140 mAh Battery',
#  'Qualcomm Snapdragon 730G Processor',
#  'OLED Display',
#  '1 Year Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G85 Processor',
#  '1 Year Manufacturer Warranty for Device and 6 months Manufacturer Warranty for In-box Accessories Including Batteries from the Date of Purchase',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '13MP Rear Camera | 8MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G80 Processor',
#  '1 Year Manufacturer Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
# ...

# %%
primarycamera_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//li"):
        primarycamera_tags.append(j.text) 
    time.sleep(5)

# %%
primarycamera_tags
# Out:
# ['6 GB RAM | 128 GB ROM',
#  '14.76 cm (5.81 inch) Full HD+ Display',
#  '12.2MP Rear Camera | 8MP Front Camera',
#  '3140 mAh Battery',
#  'Qualcomm Snapdragon 730G Processor',
#  'OLED Display',
#  '1 Year Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G85 Processor',
#  '1 Year Manufacturer Warranty for Device and 6 months Manufacturer Warranty for In-box Accessories Including Batteries from the Date of Purchase',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '13MP Rear Camera | 8MP Front Camera',
#  '5020 mAh Battery',
#  'MediaTek Helio G80 Processor',
#  '1 Year Manufacturer Warranty',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB',
#  '16.59 cm (6.53 inch) Full HD+ Display',
#  '48MP + 8MP + 2MP + 2MP | 13MP Front Camera',
#  '5020 mAh Battery',
# ...

# %%
batterycapacity_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='_3879cV']"):
        batterycapacity_tags.append(j.text) 
    time.sleep(5)

# %%
batterycapacity_tags
# Out:
# ['',
#  '6 GB & Above',
#  '4 GB',
#  '3 GB',
#  '2 GB',
#  '1 GB',
#  '512 MB - 1 GB',
#  'Less than 512 MB',
#  'SAMSUNG',
#  'Mi',
#  'OPPO',
#  'LG',
#  'ViVO',
#  'Nokia',
#  '4★ & above',
#  '3★ & above',
#  '2★ & above',
#  '1★ & above',
#  '1000 - 1999 mAh',
#  '2000 - 2999 mAh',
#  '3000 - 3999 mAh',
#  '4000 - 4999 mAh',
#  '5000 mAh & Above',
#  'Less than 1000 mAh',
#  'Buy More, Save More',
#  'Exchange Offer',
#  'No Cost EMI',
#  'Special Price',
#  'Exynos',
#  'Huawei',
#  'Mediatek',
#  'Snapdragon',
#  'Spreadtrum',
#  'Unisoc',
#  'Big Storage',
#  'Higher Performance',
#  'Long-Lasting Battery',
#  'Selfie Camera',
#  'Full HD',
#  'Full HD+',
#  'FWVGA',
#  'HD',
#  'HD+',
#  'HVGA',
#  'Quad HD',
#  'Quad HD+',
#  'QVGA',
#  'Super Retina HD Display',
#  'WVGA',
#  'Smartphones',
#  'Feature Phones',
#  'Android Q',
#  'Donut',
#  'Gingerbread',
#  'KitKat',
#  'Lollipop',
#  'Marshmallow',
#  'Nougat',
#  'Oreo',
#  'Pie',
#  '1 - 1.5 GHz',
# ...

# %%
price_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span"):
        price_tags.append(j.text) 
    time.sleep(5)

# %%
price_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  '',
#  'PRICE',
#  '?',
#  '39 MORE',
#  'Need help?',
#  'Help me decide',
#  'Showing 1 – 24 of 286 results for " pixel 4A"',
#  'pixel 4A',
#  'Sort By',
#  '',
#  'Add to Compare',
#  '4.6',
#  '22,256 Ratings & 3,870 Reviews',
#  '22,256 Ratings & 3,870 Reviews',
#  '22,256 Ratings ',
#  '&',
#  ' 3,870 Reviews',
#  '',
#  'Add to Compare',
#  '4.4',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings ',
#  '&',
#  ' 3,525 Reviews',
#  '',
#  'Add to Compare',
#  '4.4',
#  '1,18,232 Ratings & 7,940 Reviews',
#  '1,18,232 Ratings & 7,940 Reviews',
#  '1,18,232 Ratings ',
#  '&',
#  ' 7,940 Reviews',
#  '16% off',
#  '',
#  'Add to Compare',
#  '4.4',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings ',
# ...

# %%
rating_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span"):
        rating_tags.append(j.text) 
    time.sleep(5)

# %%
rating_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  '',
#  'PRICE',
#  '?',
#  '39 MORE',
#  'Need help?',
#  'Help me decide',
#  'Showing 1 – 24 of 286 results for " pixel 4A"',
#  'pixel 4A',
#  'Sort By',
#  '',
#  'Add to Compare',
#  '4.6',
#  '22,256 Ratings & 3,870 Reviews',
#  '22,256 Ratings & 3,870 Reviews',
#  '22,256 Ratings ',
#  '&',
#  ' 3,870 Reviews',
#  '',
#  'Add to Compare',
#  '4.4',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings ',
#  '&',
#  ' 3,525 Reviews',
#  '',
#  'Add to Compare',
#  '4.4',
#  '1,18,232 Ratings & 7,940 Reviews',
#  '1,18,232 Ratings & 7,940 Reviews',
#  '1,18,232 Ratings ',
#  '&',
#  ' 7,940 Reviews',
#  '16% off',
#  '',
#  'Add to Compare',
#  '4.4',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings & 3,525 Reviews',
#  '47,914 Ratings ',
# ...

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import selenium
import pandas as pd 
from selenium import webdriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
from selenium import webdriver
import time

# %%
url='https://www.google.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="87a7c25c17fe49c70adf946fe68b1919", element="dc0be6be-ba9b-4b8c-be41-988346098fde")>

# %%
search_job.send_keys('latitude coordinates map')

# %%
titlelatitudecordinatesmap_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//h1[@class='entry-title']"):
        titlelatitudecordinatesmap_tags.append(j.text) 
    time.sleep(5)

# %%
titlelatitudecordinatesmap_tags
# Out:
# ['Latitude, Longitude and Coordinate System Grids',
#  'Latitude, Longitude and Coordinate System Grids',
#  'Latitude, Longitude and Coordinate System Grids',
#  'Latitude, Longitude and Coordinate System Grids',
#  'Latitude, Longitude and Coordinate System Grids',
#  'Latitude, Longitude and Coordinate System Grids']

# %%
url='https://www.google.com/maps'
driver.get(url)

# %%
longitudecordinatemap_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//h1"):
        longitudecordinatemap_tags.append(j.text) 
    time.sleep(5)

# %%
longitudecordinatemap_tags
# Out:
# ['Find or enter latitude & longitude',
#  'Find or enter latitude & longitude',
#  'Find or enter latitude & longitude',
#  'Find or enter latitude & longitude',
#  'Find or enter latitude & longitude',
#  'Find or enter latitude & longitude',
#  'Find or enter latitude & longitude',
#  'Find or enter latitude & longitude',
#  'Find or enter latitude & longitude',
#  'Find or enter latitude & longitude']

# %%
maps_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='mk-map-node-element']"):
        maps_tags.append(j.text) 
    time.sleep(5)

# %%
maps_tags
# Out:
# ['×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
#  '×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
#  '×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
#  '×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
#  '×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
# ...

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='ZUQgzb']"):
        maps_tags.append(j.text) 
    time.sleep(5)

# %%
maps_tags
# Out:
# ['×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
#  '×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
#  '×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
#  '×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
#  '×\nRamani Orthopaedic Hospital, 5/19, 2nd Temple Street, Seshadripuram, Bengaluru - 560003, Karnataka, India\nLatitude: 13.00009 | Longitude: 77.573394\n\nGet Altitude',
# ...

# %% [markdown]
# # 6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –September 20) from trak.in.

# %%
url='https://www.trak.in/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//i[@class='fa fa-search']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="87a7c25c17fe49c70adf946fe68b1919", element="730810ec-ecb0-4139-bf95-3d19e5bc96d4")>

# %%
trak_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a[@class='post-url post-title']"):
        trak_tags.append(j.text) 
    time.sleep(5)

# %%
trak_tags
# Out:
# ['16,000 HCL Employees Get 30% Salary As Bonus; HCL Profits…',
#  'TCS Hiring Breaks All Previous Records; Revenue Hikes For…',
#  '53% Indian Firms Will Fire Employees; Only 5% Firms Will…',
#  'Vivo Beats Samsung To Become Second Largest Smartphone…',
#  '1B Indians Still Without Internet, Broadband Speed Now…',
#  'Indian Smartphone Market Fastest Growing In Asia-Pac. Logs…',
#  '16,000 HCL Employees Get 30% Salary As Bonus; HCL Profits…',
#  'TCS Hiring Breaks All Previous Records; Revenue Hikes For…',
#  '53% Indian Firms Will Fire Employees; Only 5% Firms Will…',
#  'Vivo Beats Samsung To Become Second Largest Smartphone…',
#  '1B Indians Still Without Internet, Broadband Speed Now…',
#  'Indian Smartphone Market Fastest Growing In Asia-Pac. Logs…',
#  '16,000 HCL Employees Get 30% Salary As Bonus; HCL Profits…',
#  'TCS Hiring Breaks All Previous Records; Revenue Hikes For…',
#  '53% Indian Firms Will Fire Employees; Only 5% Firms Will…',
# ...

# %% [markdown]
# # 7. Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
driver = webdriver.Chrome("chromedriver.exe")
url='https://www.digit.in/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f5deb9f0c6e68b7d2ac3cdf7ffc3499d", element="084d5c4a-64fa-47bc-b62b-a096f29b7b66")>

# %%
brand_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='searchProduct-desc']"):
        brand_tags.append(j.text) 
    time.sleep(5)

# %%
brand_tags
# Out:
# ['Asus G750JX-CV069P',
#  'Lenovo IdeaPad Y570',
#  "ASUS G53J - A 3D gamer's delight but we want more",
#  'HP Envy 15-k006tx',
#  'ASUS ROG Flow x13',
#  'ASUS ROG Cetra',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'ASUS Zephyrus G15 Ryzen 9 5900HS (2021)',
#  'Truvison TX3271',
#  'Lenovo G50-30',
#  'Asus G750JX-CV069P',
#  'Lenovo IdeaPad Y570',
#  "ASUS G53J - A 3D gamer's delight but we want more",
#  'HP Envy 15-k006tx',
#  'ASUS ROG Flow x13',
#  'ASUS ROG Cetra',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'ASUS Zephyrus G15 Ryzen 9 5900HS (2021)',
#  'Truvison TX3271',
#  'Lenovo G50-30',
#  'Asus G750JX-CV069P',
#  'Lenovo IdeaPad Y570',
#  "ASUS G53J - A 3D gamer's delight but we want more",
#  'HP Envy 15-k006tx',
#  'ASUS ROG Flow x13',
#  'ASUS ROG Cetra',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'ASUS Zephyrus G15 Ryzen 9 5900HS (2021)',
#  'Truvison TX3271',
#  'Lenovo G50-30',
#  'Asus G750JX-CV069P',
# ...

# %%
date_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span"):
        date_tags.append(j.text) 
    time.sleep(5)

# %%
date_tags
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Jun 05, 2020',
#  'Jun 05, 2020',
#  'Jun 05, 2020',
#  'Jun 03, 2020',
#  'Jun 03, 2020',
#  'Apr 24, 2015',
#  'Jan 20, 2021',
#  'Sep 03, 2019',
#  'May 28, 2015',
#  'Jun 03, 2020',
#  'Advertisements',
#  '₹ 29999 |',
#  '|',
#  '',
#  '₹ 15499 |',
#  '|',
#  '',
#  '₹ 16999 |',
#  '|',
#  '',
#  '₹ 10999 |',
#  '|',
#  '',
#  '₹ 7499 |',
#  '|',
#  '',
#  'Advertisements',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Jun 05, 2020',
#  'Jun 05, 2020',
#  'Jun 05, 2020',
#  'Jun 03, 2020',
#  'Jun 03, 2020',
#  'Apr 24, 2015',
#  'Jan 20, 2021',
#  'Sep 03, 2019',
#  'May 28, 2015',
#  'Jun 03, 2020',
#  'Advertisements',
#  '₹ 29999 |',
#  '|',
#  '',
#  '₹ 15499 |',
#  '|',
#  '',
#  '₹ 16999 |',
# ...

# %%
reviwes_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//p"):
        reviwes_tags.append(j.text) 
    time.sleep(5)

# %%
reviwes_tags
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  "Digit caters to the largest community of tech buyers, users and enthusiasts in India. The all new Digit in continues the legacy of Thinkdigit.com as one of the largest portals in India committed to technology users and buyers. Digit is also one of the most trusted names when it comes to technology reviews and buying advice and is home to the Digit Test Lab, India's most proficient center for testing and reviewing technology products.",
#  'We are about leadership-the 9.9 kind! Building a leading media company out of India.And,grooming new leaders for this promising industry.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
#  'REVIEWS',
# ...

# %%
price_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//td[@class='smprice']"):
        price_tags.append(j.text) 
    time.sleep(5)

# %%
price_tags
# Out:
# ['₹54990',
#  '₹59990',
#  '₹73719',
#  '₹59990',
#  '₹66639',
#  '₹57990',
#  '₹62479',
#  '₹54990',
#  '₹59999',
#  '₹55990',
#  '₹54990',
#  '₹59990',
#  '₹73719',
#  '₹59990',
#  '₹66639',
#  '₹57990',
#  '₹62479',
#  '₹54990',
#  '₹59999',
#  '₹55990',
#  '₹54990',
#  '₹59990',
#  '₹73719',
#  '₹59990',
#  '₹66639',
#  '₹57990',
#  '₹62479',
#  '₹54990',
#  '₹59999',
#  '₹55990',
#  '₹54990',
#  '₹59990',
#  '₹73719',
#  '₹59990',
#  '₹66639',
#  '₹57990',
#  '₹62479',
#  '₹54990',
#  '₹59999',
#  '₹55990',
#  '₹54990',
#  '₹59990',
#  '₹73719',
#  '₹59990',
#  '₹66639',
#  '₹57990',
#  '₹62479',
#  '₹54990',
#  '₹59999',
#  '₹55990',
#  '₹54990',
#  '₹59990',
#  '₹73719',
#  '₹59990',
#  '₹66639',
#  '₹57990',
#  '₹62479',
#  '₹54990',
#  '₹59999',
#  '₹55990',
#  '₹54990',
#  '₹59990',
#  '₹73719',
#  '₹59990',
#  '₹66639',
#  '₹57990',
#  '₹62479',
#  '₹54990',
#  '₹59999',
#  '₹55990',
#  '₹54990',
#  '₹59990',
#  '₹73719',
#  '₹59990',
#  '₹66639',
#  '₹57990',
# ...

# %%
All_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//td"):
        All_tags.append(j.text) 
    time.sleep(5)

# %%
All_tags
# Out:
# ['Acer Aspire 7 A715-75G-50SA',
#  'N/A',
#  '₹54990',
#  'MSI GF63 Thin 9SC-240IN',
#  'N/A',
#  '₹59990',
#  'HP Pavillion 15-bc512TX',
#  'amazon',
#  '₹73719',
#  'Acer Nitro 5 AN517-51-53JG',
#  'N/A',
#  '₹59990',
#  'Lenovo Legion Y7000 81V4000LIN',
#  'amazon',
#  '₹66639',
#  'ASUS TUF Gaming FX505DD-AL185T',
#  'amazon',
#  '₹57990',
#  'HP Pavilion Gaming 15-ec0026AX',
#  'amazon',
#  '₹62479',
#  'ASUS TUF Gaming FX505DY-BQ024T',
#  'amazon',
#  '₹54990',
#  'Mi Notebook Horizon Edition 14',
#  'amazon',
#  '₹59999',
#  'ASUS VivoBook 14 X412FJ-EK513T',
#  'flipkart',
#  '₹55990',
#  'OS',
#  ':',
#  'Windows 10',
#  'Display',
#  ':',
#  '15.6" (1920 x 1080)',
#  'Processor',
#  ':',
#  'Core i5 9th Gen | 2.4 GHz with Turbo Boost Upto 4.1 GHz',
#  'Memory',
#  ':',
#  '512 NA/8 GBGB DDR4',
#  'Weight',
#  ':',
#  '2.15',
#  'Dimension',
#  ':',
#  '363.4 x 254.5 x 23.25',
#  'Graphics Processor',
#  ':',
#  'NVIDIA Geforce GTX 1650',
#  'Price',
#  ':',
#  '₹54990',
# ...

# %% [markdown]
# # 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
import selenium
import pandas as pd 
from selenium import webdriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
from selenium import webdriver
import time

# %%
url='https://www.forbes.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//a")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f1b7f9ee68d6a050cd88e8413ffe352c", element="2731ff4b-fc13-4431-a268-4029ed8e30f9")>

# %%
search_button=driver.find_element_by_xpath("//button[@class='icon--search']")
search_button.click()

# %%
search_button.send_keys('All billionaires list')

# %%
name_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a[@class='byline__author-name']"):
        name_tags.append(j.text) 
    time.sleep(5)

# %%
name_tags
# Out:
# ['Ralph Jennings',
#  'John Hyatt',
#  'John Kang',
#  'Kerry A. Dolan',
#  'Noah Kirsch',
#  'Forbes Press Releases',
#  'Paul Westall',
#  'Sergei Klebnikov',
#  'Forbes Wealth Team',
#  'Kenrick Cai',
#  'Noah Kirsch',
#  'Chase Peterson-Withorn',
#  'Hank Tucker',
#  'Madeline Berg',
#  'Jennifer Wang',
#  "Zack O'Malley Greenburg",
#  'Ralph Jennings',
#  'John Hyatt',
#  'John Kang',
#  'Kerry A. Dolan',
#  'Noah Kirsch',
#  'Forbes Press Releases',
#  'Paul Westall',
#  'Sergei Klebnikov',
#  'Forbes Wealth Team',
#  'Kenrick Cai',
#  'Noah Kirsch',
#  'Chase Peterson-Withorn',
#  'Hank Tucker',
#  'Madeline Berg',
#  'Jennifer Wang',
#  "Zack O'Malley Greenburg",
#  'Ralph Jennings',
#  'John Hyatt',
#  'John Kang',
#  'Kerry A. Dolan',
#  'Noah Kirsch',
#  'Forbes Press Releases',
#  'Paul Westall',
#  'Sergei Klebnikov',
#  'Forbes Wealth Team',
#  'Kenrick Cai',
#  'Noah Kirsch',
#  'Chase Peterson-Withorn',
#  'Hank Tucker',
#  'Madeline Berg',
#  'Jennifer Wang',
# ...

# %%
All_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span"):
        All_tags.append(j.text) 
    time.sleep(5)

# %%
All_tags
# Out:
# ['https://www.forbes.com/billionaires',
#  "The definitive list of the World's Billionaires, presented by Forbes.",
#  'https://www.forbes.com/.../forbes-billionaires-full-list-of-the-worlds-500-richest-people',
#  "To make digesting the ranking and our work easier, what follows is a simple list of the 500 richest. They're collectively worth $4.4 trillion. Taken together, it is a roll of familiar names ...",
#  'https://www.alltopseven.com/fortune-500-list-of-companies',
#  'This post contains list of Fortune 500 companies by Forbes based on their turn over. It also contains the names of richest companies in the world which plays an important role in creating jobs and in world economy. What is Fortune 500 List? It is a list produced by Fortune Magazine annually which incorporates top 500 USA private and public companies and rank them based on their gross revenue. The first list was out in year 1955. The fierce fight always happen between the top two contenders ...',
# ...

# %%
networth_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//p"):
        networth_tags.append(j.text) 
    time.sleep(5)

# %%
networth_tags
# Out:
# ['© Info 2021. All Rights Reserved.',
#  '© Info 2021. All Rights Reserved.',
#  '© Info 2021. All Rights Reserved.',
#  '© Info 2021. All Rights Reserved.',
#  '© Info 2021. All Rights Reserved.',
#  '© Info 2021. All Rights Reserved.',
#  '© Info 2021. All Rights Reserved.',
#  '© Info 2021. All Rights Reserved.',
#  '© Info 2021. All Rights Reserved.',
#  '© Info 2021. All Rights Reserved.']

# %%
age_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a[@herf='title']"):
        age_tags.append(j.text) 
    time.sleep(5)

# %%
age_tags
# Out:
# ['',
#  'Web',
#  'Images',
#  'Videos',
#  'News',
#  'forbes top 50 richest people',
#  'forbes 500 richest people',
#  'forbes top 500 list',
#  'fortune 500 richest people',
#  'forbes 500 richest americans',
#  'fortune 500 billionaires',
#  'forbes billionaire list',
#  'forbes richest people 2021',
#  'Fortune India 500 Ranking | Fortune India',
#  'Fortune 500 List Of Companies By Forbes',
#  'Forbes Billionaires – Full List Of The 500 Richest People In The World ...',
#  'Forbes 500 - Wikipedia',
#  'Fortune 500 | Fortune',
#  "Forbes India | Business news, share market investment, India's richest ...",
#  "The World's Billionaires - Wikipedia",
#  'Bloomberg Billionaires Index',
#  "Forbes' list of the most valuable football clubs - Wikipedia",
#  'List of French billionaires by net worth - Wikipedia',
#  'Global 500 | Fortune',
#  'Prev',
#  '1',
#  '3',
#  '4',
#  '5',
#  'Next',
#  'forbes top 50 richest people',
#  'forbes 500 richest people',
#  'forbes top 500 list',
# ...

# %% [markdown]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Videos

# %%
import selenium
import pandas as pd 
from selenium import webdriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
from selenium import webdriver
import time

# %%
url='https://www.youtube.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="98cb05bff1e55ad98f4e7849b6280bcc", element="72256a39-79ad-4a75-a1ae-7de2616d8521")>

# %%
comments_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//span[@class='style-scope yt-formatted-string']"):
        comments_tags.append(j.text) 
    time.sleep(5)

# %%
comments_tags
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Presenting the "Amma" Lyrical Video Song from LISA Kannada Movie , Written & Directed by Muthu, And Produced by Suryakanth Korali, Co Producer Avinash Jhankatti, Devsree, Dayanand, Muthu, Roopa Nataraj, Parvathi, Saakshi, Shravya, Ganapathi, Thejasvini',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '313',
#  'Comments',
#  'ಏನ್ ಹೇಳ್ಬೇಕೋ ಗೊತ್ತಾಗ್ತಿಲ್ಲ ಈ ಹಾಡು ಬರೆದವರಿಗೆ ಮತ್ತೆ ಹಾಡು ಹಾಡಿದವರಿಗೆ ನನ್ನ 🙏🙏🙏',
#  '',
#  'ಲವ್ ಯು ಅಮ್ಮ 👩👩👩',
#  'View',
#  '2',
#  'replies',
#  'Chindi lyrics guru😍😭emotional agode lyrics keli ❤️',
#  '',
#  '',
#  "Anuradha ಭಟ್ ma'am ನಿಮ್ ಬಗ್ಗೆ mathado hage illa ❤️lovely 😍😘❤️",
#  '🙏 ನ್ಯಾಯ ನಿನ್ನ ಪರವಗಿದ್ದರೂ ಸರಿ.... ',
#  '',
#  'ತಾಯಿಯ ಜೊತೆಗೆ ವಾದ ಮಾಡ ಬೇಡ.... ',
#  '',
# ...

# %%
time_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//a[@class='yt-simple-endpoint style-scope yt-formatted-string']"):
        time_tags.append(j.text) 
    time.sleep(5)

# %%
time_tags
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '#AmmaLyricalSong',
#  '#Lisa',
#  '#Muthu',
#  'A2 MUSIC',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '6 months ago',
#  '',
#  '1 year ago',
#  '',
#  '9 months ago (edited)',
#  '',
#  '1 year ago',
#  '',
#  '1 year ago',
#  '',
#  '6 months ago',
#  '',
#  '6 months ago',
#  '',
#  '1 year ago',
#  '',
#  '10 months ago',
#  '',
#  '6 months ago',
#  '',
#  '1 year ago',
#  '',
#  '1 year ago',
#  '',
#  '1 year ago',
#  '',
#  '6 months ago',
#  '',
#  '7 months ago',
#  '',
#  '1 year ago',
#  '',
#  '7 months ago',
#  '',
#  '6 months ago',
#  '',
#  '7 months ago',
#  '',
#  '11 months ago',
#  '',
#  '7 months ago',
#  '',
#  '1 year ago',
#  '',
#  '4 months ago',
#  '',
# ...

# %%
vote_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']"):
        vote_tags.append(j.text) 
    time.sleep(5)

# %%
vote_tags
# Out:
# ['',
#  '68',
#  '',
#  '33',
#  '',
#  '75',
#  '',
#  '16',
#  '',
#  '14',
#  '',
#  '27',
#  '',
#  '34',
#  '',
#  '6',
#  '',
#  '22',
#  '',
#  '15',
#  '',
#  '4',
#  '',
#  '15',
#  '',
#  '15',
#  '',
#  '15',
#  '',
#  '5',
#  '',
#  '20',
#  '',
#  '12',
#  '',
#  '7',
#  '',
#  '6',
#  '',
#  '3',
#  '',
#  '68',
#  '',
#  '33',
#  '',
#  '75',
#  '',
#  '16',
#  '',
#  '14',
#  '',
#  '27',
#  '',
#  '34',
#  '',
#  '6',
#  '',
#  '22',
#  '',
#  '15',
#  '',
#  '4',
#  '',
#  '15',
#  '',
#  '15',
#  '',
#  '15',
#  '',
#  '5',
#  '',
#  '20',
#  '',
#  '12',
#  '',
#  '7',
#  '',
#  '6',
#  '',
#  '3',
#  '',
#  '68',
#  '',
#  '33',
#  '',
#  '75',
#  '',
#  '16',
#  '',
#  '14',
#  '',
#  '27',
#  '',
#  '34',
#  '',
#  '6',
#  '',
#  '22',
#  '',
#  '15',
#  '',
#  '4',
#  '',
#  '15',
#  '',
#  '15',
#  '',
#  '15',
#  '',
#  '5',
#  '',
#  '20',
#  '',
#  '12',
#  '',
#  '7',
#  '',
#  '6',
#  '',
#  '3',
#  '',
#  '68',
#  '',
#  '33',
#  '',
#  '75',
#  '',
# ...

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name,distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
import selenium
import pandas as pd 
from selenium import webdriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
from selenium import webdriver
import time

# %%
url='https://www.hostelworld.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c5d641992e5212940ee657bd910682a4", element="8c9e8c9a-9d26-41b8-b478-09099abdac01")>

# %%
name_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a"):
        name_tags.append(j.text) 
    time.sleep(5)

# %%
name_tags
# Out:
# ['',
#  '',
#  'Selina Camden\nHostel - 5.5km from city centre',
#  'NEW',
#  'From Rs3155',
#  '',
#  'Park Villa\nHostel - 6.3km from city centre',
#  '9.3\nSuperb',
#  'From Rs2414',
#  '1\n/\n30',
#  "St Christopher's Village",
#  'Hostel - 1.8km from city centre Show on Map',
#  '8.9\nFabulous\n10814 Total Reviews',
#  'Privates From\nRs3758\nDorms From\nRs1472',
#  'View',
#  '1\n/\n30',
#  'Generator London',
#  'Hostel - 3km from city centre Show on Map',
#  '7.5\nVery Good\n6729 Total Reviews',
#  'Privates From\nRs8344\nDorms From\nRs2034',
#  'View',
#  '1\n/\n30',
#  'PubLove @ The Crown, Battersea',
#  'Hostel - 4.7km from city centre Show on Map',
#  '7.9\nVery Good\n204 Total Reviews',
#  'Privates From\nRs8385\nDorms From\nRs1324',
#  'View',
#  '1\n/\n14',
#  'Leman House',
#  'Hostel - 3.6km from city centre Show on Map',
#  'No Rating\n13 Total Reviews',
#  'Privates From\nRs5896\nNo Dorms Available',
#  'View',
#  '1\n/\n22',
# ...

# %%
distance_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='description']"):
        distance_tags.append(j.text) 
    time.sleep(5)

# %%
distance_tags
# Out:
# ['Hostel - 1.8km from city centre',
#  'Hostel - 3km from city centre',
#  'Hostel - 4.7km from city centre',
#  'Hostel - 3.6km from city centre',
#  'Hostel - 8.2km from city centre',
#  'Hostel - 0.5km from city centre',
#  'Hostel - 3.6km from city centre',
#  'Hostel - 3.6km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 1.7km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hostel - 2.2km from city centre',
#  'Hostel - 2.4km from city centre',
#  'Hostel - 3.6km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hostel - 10km from city centre',
#  'Hostel - 2km from city centre',
#  'Hostel - 3.5km from city centre',
#  'Hostel - 3.2km from city centre',
#  'Hostel - 7.1km from city centre',
#  'Hostel - 0.7km from city centre',
#  'Hostel - 10.4km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hostel - 7.3km from city centre',
#  'Hostel - 1.8km from city centre',
#  'Hostel - 4.9km from city centre',
# ...

# %%
ratings_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='score orange big']"):
        ratings_tags.append(j.text) 
    time.sleep(5)

# %%
ratings_tags
# Out:
# ['8.9',
#  '7.5',
#  '7.9',
#  '8.7',
#  '7.7',
#  '9.3',
#  '8.0',
#  '6.9',
#  '9.6',
#  '9.1',
#  '10',
#  '8.8',
#  '9.0',
#  '9.7',
#  '10',
#  '9.7',
#  '7.8',
#  '9.5',
#  '9.2',
#  '7.8',
#  '8.6',
#  '9.0',
#  '7.5',
#  '7.8',
#  '8.3',
#  '8.9',
#  '7.5',
#  '7.9',
#  '8.7',
#  '7.7',
#  '9.3',
#  '8.0',
#  '6.9',
#  '9.6',
#  '9.1',
#  '10',
#  '8.8',
#  '9.0',
#  '9.7',
#  '10',
#  '9.7',
#  '7.8',
#  '9.5',
#  '9.2',
#  '7.8',
#  '8.6',
#  '9.0',
#  '7.5',
#  '7.8',
#  '8.3',
#  '8.9',
#  '7.5',
#  '7.9',
#  '8.7',
#  '7.7',
#  '9.3',
#  '8.0',
#  '6.9',
#  '9.6',
#  '9.1',
#  '10',
#  '8.8',
#  '9.0',
#  '9.7',
#  '10',
#  '9.7',
#  '7.8',
#  '9.5',
#  '9.2',
#  '7.8',
#  '8.6',
#  '9.0',
#  '7.5',
#  '7.8',
#  '8.3',
#  '8.9',
#  '7.5',
#  '7.9',
#  '8.7',
#  '7.7',
#  '9.3',
#  '8.0',
#  '6.9',
#  '9.6',
#  '9.1',
#  '10',
#  '8.8',
#  '9.0',
#  '9.7',
#  '10',
#  '9.7',
#  '7.8',
#  '9.5',
#  '9.2',
#  '7.8',
#  '8.6',
#  '9.0',
#  '7.5',
#  '7.8',
#  '8.3',
# ...

# %%
reviwes_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='reviews']"):
        reviwes_tags.append(j.text) 
    time.sleep(5)

# %%
reviwes_tags
# Out:
# ['10814 Total Reviews',
#  '6729 Total Reviews',
#  '204 Total Reviews',
#  '13 Total Reviews',
#  '443 Total Reviews',
#  '183 Total Reviews',
#  '248 Total Reviews',
#  '13123 Total Reviews',
#  '0 Total Reviews',
#  '3930 Total Reviews',
#  '391 Total Reviews',
#  '8706 Total Reviews',
#  '128 Total Reviews',
#  '513 Total Reviews',
#  '193 Total Reviews',
#  '4558 Total Reviews',
#  '3946 Total Reviews',
#  '8109 Total Reviews',
#  '3165 Total Reviews',
#  '25 Total Reviews',
#  '2399 Total Reviews',
#  '878 Total Reviews',
#  '11320 Total Reviews',
#  '3652 Total Reviews',
#  '593 Total Reviews',
#  '6323 Total Reviews',
#  '997 Total Reviews',
#  '357 Total Reviews',
#  '1405 Total Reviews',
#  '3393 Total Reviews',
#  '10814 Total Reviews',
#  '6729 Total Reviews',
#  '204 Total Reviews',
#  '13 Total Reviews',
#  '443 Total Reviews',
#  '183 Total Reviews',
#  '248 Total Reviews',
#  '13123 Total Reviews',
#  '0 Total Reviews',
#  '3930 Total Reviews',
# ...

# %%
private_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='price title-5']"):
        private_tags.append(j.text) 
    time.sleep(5)

# %%
private_tags
# Out:
# ['Rs3758',
#  'Rs1472',
#  'Rs8344',
#  'Rs2034',
#  'Rs8385',
#  'Rs1324',
#  'Rs5896',
#  'Rs5275',
#  'Rs2345',
#  'Rs4138',
#  'Rs1634',
#  'Rs8238',
#  'Rs2750',
#  'Rs13023',
#  'Rs3155',
#  'Rs4187',
#  'Rs1117',
#  'Rs6310',
#  'Rs1586',
#  'Rs6896',
#  'Rs2172',
#  'Rs1655',
#  'Rs6699',
#  'Rs2839',
#  'Rs11172',
#  'Rs943',
#  'Rs2138',
#  'Rs3341',
#  'Rs7119',
#  'Rs1763',
#  'Rs2110',
#  'Rs2886',
#  'Rs1484',
#  'Rs4138',
#  'Rs6896',
#  'Rs2172',
#  'Rs2483',
#  'Rs1621',
#  'Rs4793',
#  'Rs1679',
#  'Rs6172',
#  'Rs1896',
#  'Rs1208',
#  'Rs4655',
#  'Rs1933',
#  'Rs2523',
#  'Rs1427',
#  'Rs3758',
#  'Rs1472',
#  'Rs8344',
#  'Rs2034',
#  'Rs8385',
#  'Rs1324',
#  'Rs5896',
#  'Rs5275',
#  'Rs2345',
#  'Rs4138',
#  'Rs1634',
#  'Rs8238',
#  'Rs2750',
#  'Rs13023',
#  'Rs3155',
#  'Rs4187',
#  'Rs1117',
#  'Rs6310',
#  'Rs1586',
#  'Rs6896',
#  'Rs2172',
#  'Rs1655',
#  'Rs6699',
#  'Rs2839',
#  'Rs11172',
#  'Rs943',
#  'Rs2138',
#  'Rs3341',
#  'Rs7119',
# ...

# %%
dorms_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='price title-5']"):
        dorms_tags.append(j.text) 
    time.sleep(5)

# %%
dorms_tags
# Out:
# ['Rs3758',
#  'Rs1472',
#  'Rs8344',
#  'Rs2034',
#  'Rs8385',
#  'Rs1324',
#  'Rs5896',
#  'Rs5275',
#  'Rs2345',
#  'Rs4138',
#  'Rs1634',
#  'Rs8238',
#  'Rs2750',
#  'Rs13023',
#  'Rs3155',
#  'Rs4187',
#  'Rs1117',
#  'Rs6310',
#  'Rs1586',
#  'Rs6896',
#  'Rs2172',
#  'Rs1655',
#  'Rs6699',
#  'Rs2839',
#  'Rs11172',
#  'Rs943',
#  'Rs2138',
#  'Rs3341',
#  'Rs7119',
#  'Rs1763',
#  'Rs2110',
#  'Rs2886',
#  'Rs1484',
#  'Rs4138',
#  'Rs6896',
#  'Rs2172',
#  'Rs2483',
#  'Rs1621',
#  'Rs4793',
#  'Rs1679',
#  'Rs6172',
#  'Rs1896',
#  'Rs1208',
#  'Rs4655',
#  'Rs1933',
#  'Rs2523',
#  'Rs1427',
#  'Rs3758',
#  'Rs1472',
#  'Rs8344',
#  'Rs2034',
#  'Rs8385',
#  'Rs1324',
#  'Rs5896',
#  'Rs5275',
#  'Rs2345',
#  'Rs4138',
#  'Rs1634',
#  'Rs8238',
#  'Rs2750',
#  'Rs13023',
#  'Rs3155',
#  'Rs4187',
#  'Rs1117',
#  'Rs6310',
#  'Rs1586',
#  'Rs6896',
#  'Rs2172',
#  'Rs1655',
#  'Rs6699',
#  'Rs2839',
#  'Rs11172',
#  'Rs943',
#  'Rs2138',
#  'Rs3341',
#  'Rs7119',
# ...

# %%
facilities_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='label']"):
        facilities_tags.append(j.text) 
    time.sleep(5)

# %%
facilities_tags
# Out:
# ['Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free Breakfast',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free Breakfast',
# ...

# %%
property_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//h4[@class='title-4']"):
        property_tags.append(j.text) 
    time.sleep(5)

# %%
property_tags
# Out:
# ['All Properties',
#  'All Properties',
#  'All Properties',
#  'All Properties',
#  'All Properties',
#  'All Properties',
#  'All Properties',
#  'All Properties',
#  'All Properties',
#  'All Properties',
#  'Hostelworld says',
#  'Property Description',
#  'Check Availability',
#  'Reviews & Ratings',
#  'Facilities',
#  'Awards',
#  'Hostelworld says',
#  'Property Description',
#  'Check Availability',
#  'Reviews & Ratings',
#  'Facilities',
#  'Awards',
#  'Hostelworld says',
#  'Property Description',
#  'Check Availability',
#  'Reviews & Ratings',
#  'Facilities',
#  'Awards',
#  'Hostelworld says',
#  'Property Description',
#  'Check Availability',
#  'Reviews & Ratings',
#  'Facilities',
#  'Awards',
#  'Hostelworld says',
#  'Property Description',
#  'Check Availability',
#  'Reviews & Ratings',
#  'Facilities',
#  'Awards',
#  'Hostelworld says',
#  'Property Description',
#  'Check Availability',
#  'Reviews & Ratings',
#  'Facilities',
#  'Awards',
# ...
